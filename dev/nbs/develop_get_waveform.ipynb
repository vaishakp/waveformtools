# %%
import numpy as np
import lal, lalsimulation
from lalsimulation import SimInspiralChooseTDWaveform, SimInspiralGetApproximantFromString
import matplotlib.pyplot as plt
from lal import MSUN_SI, PC_SI, DictInsertINT8Value, DictEntryGetValue, DictLookupINT4Value

# %%
lalsimulation.IMRPhenomCPH

# %%
mass1=10*MSUN_SI
mass2= 10*MSUN_SI
spin1x=0
spin1y=0
spin1z=0
spin2x=0
spin2y=0
spin2z=0

distance=100*1e6*PC_SI
inclination = np.pi/2
phi_ref=0
longAscNodes = 0
eccentricity=0
meanPerAno=0
delta_t = 1/4096
f_min = 13.33
f_ref=20
params = lal.CreateDict()
approximant=SimInspiralGetApproximantFromString('IMRPhenomXPHM')

# %%
hp, hc = SimInspiralChooseTDWaveform(mass1,
                                     mass2,
                                     spin1x,
                                     spin1y,
                                     spin1z,
                                     spin2x,
                                     spin2y,
                                     spin2z,
                                     distance,
                                     inclination,
                                     phi_ref,
                                     longAscNodes,
                                     eccentricity,
                                     meanPerAno,
                                     delta_t,
                                     f_min,
                                     f_ref,
                                     params,
                                     approximant
)

# %%
hp.data.data
# Out:
# array([-0.00000000e+00, -1.68007671e-30, -3.78919117e-30, ...,
#        -2.99776370e-26, -1.93140811e-26, -3.53297551e-27])

# %%
hp.data.data
# Out:
# array([-0.00000000e+00, -1.68007712e-30, -3.78919273e-30, ...,
#        -2.99778356e-26, -1.93141065e-26, -3.53296628e-27])

# %%
time = np.arange(len(hp.data.dainsert values to Dict inta))/4096

# %%
plt.plot(time, hp.data.data)

# %%
params
# Out:
# <Swig Object of type 'tagLALDict *' at 0x7f334033a1b0>

# %%
lal.CreateDict({'a' : 1})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 lal.CreateDict({'a' : 1})
#
# TypeError: lal._lal.CreateDict() takes no arguments (1 given)

# %%
params.append({"a" : 1})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 params.append({"a" : 1})
#
# TypeError: Attempt to append a non SwigPyObject

# %%
DictInsertINT8Value(params, "PhenomXHMReleaseVersion", 122022)
# Out:
# 0

# %%
DictEntryGetValue(params)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 DictEntryGetValue(params)
#
# TypeError: in method 'DictEntryGetValue', argument 1 of type 'LALDictEntry const *'

# %%
params.
# Out:
# <Swig Object of type 'tagLALDict *' at 0x7f334033a1b0>

# %%
DictLookupINT4Value(params, "PhenomXHMReleaseVersion")
# Out:
# XLAL Error - XLALValueGetINT4 (/home/conda/feedstock_root/build_artifacts/lal-split_1724321295398/work/lib/tools/LALValue.c:243): Check failed: value->type == LAL_I4_TYPE_CODE
# XLAL Error
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 DictLookupINT4Value(params, "PhenomXHMReleaseVersion")
#
# RuntimeError: Wrong or unknown type
#  - XLALValueGetINT4 (/home/conda/feedstock_root/build_artifacts/lal-split_1724321295398/work/lib/tools/LALValue.c:243): Wrong or unknown type

# %%
from lalsimulation import SimInspiralWaveformParamsInsertPhenomXHMReleaseVersion, SimInspiralWaveformParamsInsertPhenomXPrecVersion, SimInspiralWaveformParamsLookupPhenomXPrecVersion

# %%
SimInspiralWaveformParamsInsertPhenomXHMReleaseVersion(params, 122022)
# Out:
# 0

# %%
SimInspiralWaveformParamsInsertPhenomXPrecVersion(params, 320)
# Out:
# 0

# %%
SimInspiralWaveformParamsLookupPhenomXPrecVersion(params)
# Out:
# 320

# %%
from waveformtools.models.lal import LALWaveformModel
# Out:
# /home/vaishakprasad/Projects/custom_libraries/waveformtools/waveformtools
# /home/vaishakprasad/Projects/custom_libraries/waveformtools/waveformtools/models/waveform_models.py:1: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   from lal import CreateDict

# %%
imr_model = LALWaveformModel(parameters_dict={"approximant":'IMRPhenomXPHM',
                                              'delta_t' : 1/4096,
                                              'f_lower' : 13.33,
                                              'f_ref': 20 })
# Out:
# Super init

# %%
eob_model = LALWaveformModel(parameters_dict={"approximant":'SEOBNRv4PHM',
                                              'delta_t' : 1/4096,
                                              'f_lower' : 13.33,
                                              'f_ref': 20 })
# Out:
# Super init

# %%
sur_model = LALWaveformModel(parameters_dict={"approximant":'NRSur7dq4',
                                              'delta_t' : 1/4096,
                                              'f_lower' : 0,
                                              'f_ref': 20 })
# Out:
# Super init

# %%
imr_model.approximant
# Out:
# 'IMRPhenomXPHM'

# %%
eob_model

# %%
from pycbc.detector import Detector

ifo = Detector('L1')

# %%
# IMR values
mass_ratio=  0.9162626762345066
chirp_mass= 28.470041284599915
spin1x =   -0.09560636991752257
spin1y =   -0.40149240588076873
spin1z =   -0.16237417464251797
spin2x =   -0.08955307070995253
spin2y =   -0.13071782986776623
spin2z =    0.15082844936642792
coa_phase = 2.8577459673521304
distance =  322.3030269667857
inclination = 1.5928636369679507
ra     =      3.708005863616251
dec    =     0.5581684370260908
psi    =     2.724044904277288
#t_coal =      1376089759.805
geocent_time = 1376089759.8269203


from waveformtools.waveformtools import compute_masses_from_mass_ratio_and_chirp_mass

mass_1, mass_2 = compute_masses_from_mass_ratio_and_chirp_mass(mass_ratio, chirp_mass)

delta_t = ifo.time_delay_from_earth_center(ra, dec, geocent_time)
t_coal = geocent_time + delta_t

injection_parameters_imr = {
    'mass1' : mass_1,
    'mass2' : mass_2,
 #   'mass_ratio': mass_ratio,
 #   'chirp_mass': chirp_mass,
    'spin1x' :    spin1x,
    'spin1y' :    spin1y,
    'spin1z' :    spin1z,
    'spin2x' :    spin2x,
    'spin2y' :    spin2y,
    'spin2z' :    spin2z,
    'coa_phase' : coa_phase,
    'distance' : distance,
    'inclination' : inclination,
    'ra'     :    ra,
    'dec'    :    dec,
    'psi'    :    psi,
    't_coal' : t_coal,
    
}

# %%
hp, hc = imr_model.get_td_waveform(**injection_parameters_imr)

# %%
# %%timeit
hp, hc = imr_model.get_td_waveform(**injection_parameters_imr)
# Out:
# 18.7 ms ± 616 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
hp, hc = imr_model.get_td_waveform(injection_parameters_imr)
# Out:
# 18.9 ms ± 243 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
hp, hc = eob_model.get_td_waveform(injection_parameters_imr)
# Out:
# 1.58 s ± 18.2 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
hp, hc = sur_model.get_td_waveform(**injection_parameters_imr)
# Out:
# 13 ms ± 831 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
plt.plot(hp[15000:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 plt.plot(hp[15000:])
#
# NameError: name 'plt' is not defined

# %%
hp
# Out:
# array([-2.41456792e-22, -2.43517491e-22, -2.45473653e-22, ...,
#        -0.00000000e+00, -0.00000000e+00, -0.00000000e+00])

# %%
plt.plot(hp[:])

# %%
from lalsimulation.gwsignal.models import gwsignal_get_waveform_generator
# Out:
# /home/vaishakprasad/Installations/anaconda/envs/gw/lib/python3.12/site-packages/lalsimulation/lalsimulation.py:8: UserWarning: Wswiglal-redir-stdio:
#
# SWIGLAL standard output/error redirection is enabled in IPython.
# This may lead to performance penalties. To disable locally, use:
#
# with lal.no_swig_redirect_standard_output_error():
#     ...
#
# To disable globally, use:
#
# lal.swig_redirect_standard_output_error(False)
#
# Note however that this will likely lead to error messages from
# LAL functions being either misdirected or lost when called from
# Jupyter notebooks.
#
# To suppress this warning, use:
#
# import warnings
# warnings.filterwarnings("ignore", "Wswiglal-redir-stdio")
# import lal
#
#   import lal

# %%
sg =  gwsignal_get_waveform_generator(waveform_approximant='SEOBNRv5PHM')

# %%
sg

# %%
sg.generate_td_waveform(**injection_parameters_imr)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Installations/anaconda/envs/gw/lib/python3.12/site-packages/lalsimulation/gwsignal/core/utils.py:165, in check_dict_parameters(waveform_dict, generic_param_dict)
#     164 elif k in pc.units_dict[default_unit_sys].keys():
# --> 165     try : waveform_dict[k].unit #Check if it has units at all. Otherwise will give no clue about the parameter giving error
#     166     except: raise(TypeError( ("Parameter {} does not have units, please pass a parameter with astropy units equivalent to u.[{}]".format(k,pc.units_dict[default_unit_sys][k]))))
#
# AttributeError: 'float' object has no attribute 'unit'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ...

# %%
from pycbc.waveform import get_td_waveform

# %%
# %%timeit
get_td_waveform(approximant='SEOBNRv5PHM', 
                f_lower=13.33,
                delta_t=1/4096,
                mass1=mass_1,
                mass2=mass_2,
                **injection_parameters_imr)
# Out:
# 85.5 ms ± 1.45 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
get_td_waveform(approximant='IMRPhenomXPHM', 
                f_lower=13.33,
                delta_t=1/4096,
                mass1=mass_1,
                mass2=mass_2,
                **injection_parameters_imr)
# Out:
# 62.8 ms ± 600 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
hp, hc = imr_model.get_td_waveform(injection_parameters_imr)
# Out:
# 18.4 ms ± 118 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
hp, hc = eob_model.get_td_waveform(**injection_parameters_imr)
# Out:
# 1.54 s ± 18.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
get_td_waveform(approximant='NRSur7dq4', 
                f_lower=20,
                delta_t=1/4096,
                mass1=mass_1,
                mass2=mass_2,
                **injection_parameters_imr)
# Out:
# 14.2 ms ± 563 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
